# %%
import geopandas as gpd
import matplotlib.pyplot as plt

# Read the GeoJSON data from the file
gdf = gpd.read_file("data.geojson")

# Print the GeoDataFrame
print(gdf)

# Plot the GeoDataFrame
gdf.plot()
plt.show()
# Out:
#                     name  category  area_km2  height_m  length_km  \
# 0           Central Park      Park      3.41       NaN        NaN
# 1  Empire State Building  Landmark       NaN     443.2        NaN
# 2           Hudson River     River       NaN       NaN      507.0
#
#                                             geometry
# 0  POLYGON ((-73.96570 40.78280, -73.95580 40.776...
# 1                         POINT (-73.98570 40.74880)
# 2  LINESTRING (-74.01630 40.70110, -73.98970 40.7...
